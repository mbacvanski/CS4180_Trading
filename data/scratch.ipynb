# %%
from utils.experiment import ExperimentResult, plot_profits, visualize_experiment
plot_profits(ExperimentResult.from_file("./semigradient_sarsa_2022-11-20--14-48-19.pickle"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 from utils.experiment import ExperimentResult, plot_profits, visualize_experiment
# ----> 2 plot_profits(ExperimentResult.from_file("./semigradient_sarsa_2022-11-20--14-48-19.pickle"))
#
# File ~/School/CS4180_Trading/utils/experiment.py:48, in plot_profits(r)
#      46 def plot_profits(r: ExperimentResult):
#      47     plt.plot(range(0, len(r.profits)), r.profits, 'blue', label='Agent profit')
# ---> 48     plt.plot(range(0, len(r.profits)), r.max_possible_profits, 'green', label='Maximum possible profits')
#      50     plt.title(f'Profits per training episode. Avg={np.average(r.profits)}')
#      51     plt.xlabel('Episode')
#
# AttributeError: 'ExperimentResult' object has no attribute 'max_possible_profits'

# %%
plot_profits(ExperimentResult.from_file("./semigradient_sarsa_2022-11-20--14-43-28.pickle"))
